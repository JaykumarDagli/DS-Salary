# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('cleaned_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         337 non-null    int64
#  1   Job Description    337 non-null    object
#  2   Rating             337 non-null    int64
#  3   Company Name       337 non-null    object
#  4   Location           337 non-null    object
#  5   Headquarters       337 non-null    object
#  6   Size               337 non-null    object
#  7   Founded            337 non-null    int64
#  8   Type of ownership  337 non-null    object
#  9   Industry           337 non-null    object
#  10  Sector             337 non-null    object
#  11  Revenue            337 non-null    object
#  12  Competitors        337 non-null    object
#  13  Annual Min         337 non-null    int64
#  14  Annual Max         337 non-null    int64
#  15  Avg Salary         337 non-null    float64
# ...

# %%
df_model = df[['Avg Salary','Rating', 'Size','Type of ownership','Industry', 'Sector', 'Revenue','Competitors','hq_base','lochq','age','python_yn','spark_yn','aws_yn','excel_yn','job_type','job_seniority','job_len']]

# %%
df_dum = pd.get_dummies(df_model)

# %%
df_dum
# Out:
#      Avg Salary  Rating  lochq  age  python_yn  spark_yn  aws_yn  excel_yn  \
# 0      906841.0       3      0   53          1         1       0         0
# 1      229500.0       3      0   22          1         0       0         0
# 2     2538462.0       3      0   43          1         0       0         0
# 3     1566457.0       4      0   26          1         1       1         1
# 4      434000.0       4      0   25          1         0       0         0
# ..          ...     ...    ...  ...        ...       ...     ...       ...
# 332    223872.0       3      0   -1          0         0       0         0
# 333     20500.0       3      1   -1          1         0       0         0
# 334     54000.0       3      0   -1          1         1       0         0
# 335    752000.0       3      0   11          0         0       0         0
# 336    222500.0       3      0   -1          0         0       0         0
#
# ...
