# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df=pd.read_csv('glassdoor_jobs_cleaned.csv')

# %%
df.head()
# Out:
#                                         Job Title  \
# 0                                  Data Scientist
# 1  Associate Business Intelligence Data Scientist
# 2                  Scientist, Population Genomics
# 3                                 Data Analyst II
# 4                               Sensory Scientist
#
#                Salary Estimate  \
# 0  $64K-$106K (Glassdoor est.)
# 1  $64K-$106K (Glassdoor est.)
# 2  $64K-$106K (Glassdoor est.)
# 3  $64K-$106K (Glassdoor est.)
# 4  $64K-$106K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 1  Blending customer advisory, customer support, ...     3.2
# 2  WuXi NextCODE is seeking a motivated Scientist...     2.9
# 3  The Data Analyst II is responsible for data en...     4.2
# 4  A leading food production company in St. Louis...     3.8
#
#                 Company Name         Location   Headquarters  \
# 0                    ManTech    Chantilly, VA    Herndon, VA
# 1        Carousel Industries       Exeter, RI     Exeter, RI
# 2        Carousel Industries    Cambridge, MA  Cambridge, MA
# 3  Insight Enterprises, Inc.        Plano, TX      Tempe, AZ
# 4                NIC Infotek  Saint Louis, MO      Tampa, FL
#
#                       Size  Founded  Type of ownership  ... pytorch_yn  \
# 0  5001 to 10000 employees     1968   Company - Public  ...          0
# 1   1001 to 5000 employees     1992  Company - Private  ...          0
# 2    501 to 1000 employees     2015  Company - Private  ...          0
# 3  5001 to 10000 employees     1988   Company - Public  ...          0
# 4      51 to 200 employees     2004   Company - Public  ...          0
#
#   algo_yn stats_yn tableau_yn        job_type  job_type_num  seniority  \
# 0       1        1          0  data scientist             3         na
# 1       0        1          1  data scientist             3         na
# 2       0        1          0              na             7         na
# 3       0        0          0         analyst             1         na
# 4       0        1          0              na             7         na
#
#   seniority_num  len_desc  num_comp
# 0             2      3962         0
# 1             2      5358         0
# 2             2      3183         0
# 3             2      4218         3
# 4             2      1833         0
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'State', 'jobhq', 'age',
#        'python_yn', 'r_yn', 'aws_yn', 'spark_yn', 'hadoop_yn', 'docker_yn',
#        'sql_yn', 'linux_yn', 'flask_yn', 'django_yn', 'tensorflow_yn',
#        'keras_yn', 'pytorch_yn', 'algo_yn', 'stats_yn', 'tableau_yn',
#        'job_type', 'job_type_num', 'seniority', 'seniority_num', 'len_desc',
#        'num_comp'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                count         mean          std    min     25%     50%  \
# Rating         940.0     3.868191     0.622697    1.5     3.5     3.9
# Founded        940.0  1787.376596   590.838475   -1.0  1951.0  1995.0
# min_salary     940.0    87.503191    22.219953   55.0    64.0    96.0
# max_salary     940.0   136.112766    35.119756   69.0   101.0   140.0
# avg_salary     940.0   111.807979    27.917708   63.5    85.0   124.0
# jobhq          940.0     0.454255     0.498168    0.0     0.0     0.0
# age            940.0    34.725532    43.299059   -1.0     8.0    21.0
# python_yn      940.0     0.745745     0.435674    0.0     0.0     1.0
# r_yn           940.0     0.426596     0.494846    0.0     0.0     0.0
# aws_yn         940.0     0.268085     0.443198    0.0     0.0     0.0
# spark_yn       940.0     0.285106     0.451705    0.0     0.0     0.0
# hadoop_yn      940.0     0.264894     0.441511    0.0     0.0     0.0
# docker_yn      940.0     0.029787     0.170090    0.0     0.0     0.0
# sql_yn         940.0     0.581915     0.493507    0.0     0.0     1.0
# linux_yn       940.0     0.097872     0.297300    0.0     0.0     0.0
# flask_yn       940.0     0.014894     0.121192    0.0     0.0     0.0
# django_yn      940.0     0.011702     0.107599    0.0     0.0     0.0
# tensorflow_yn  940.0     0.168085     0.374141    0.0     0.0     0.0
# keras_yn       940.0     0.068085     0.252026    0.0     0.0     0.0
# pytorch_yn     940.0     0.092553     0.289960    0.0     0.0     0.0
# algo_yn        940.0     0.411702     0.492404    0.0     0.0     0.0
# stats_yn       940.0     0.719149     0.449654    0.0     0.0     1.0
# tableau_yn     940.0     0.190426     0.392846    0.0     0.0     0.0
# job_type_num   940.0     3.294681     1.471553    1.0     3.0     3.0
# seniority_num  940.0     1.827660     0.377877    1.0     2.0     2.0
# len_desc       940.0  3624.280851  1674.938897  119.0  2627.0  3508.0
# num_comp       940.0     0.869149     1.280186    0.0     0.0     0.0
#
#                    75%      max
# Rating            4.30      5.0
# Founded        2007.25   2019.0
# min_salary       99.00    141.0
# max_salary      156.00    225.0
# avg_salary      126.50    183.0
# jobhq             1.00      1.0
# age              42.00    330.0
# python_yn         1.00      1.0
# r_yn              1.00      1.0
# aws_yn            1.00      1.0
# spark_yn          1.00      1.0
# hadoop_yn         1.00      1.0
# docker_yn         0.00      1.0
# sql_yn            1.00      1.0
# linux_yn          0.00      1.0
# flask_yn          0.00      1.0
# django_yn         0.00      1.0
# tensorflow_yn     0.00      1.0
# keras_yn          0.00      1.0
# pytorch_yn        0.00      1.0
# algo_yn           1.00      1.0
# stats_yn          1.00      1.0
# tableau_yn        0.00      1.0
# job_type_num      3.00      9.0
# seniority_num     2.00      2.0
# len_desc       4424.50  14110.0
# num_comp          2.00      3.0

# %%
df['Rating'].hist(grid=False)

# %% [markdown]
# Histogram is right skewed with many ratings with value greater than 3.5

# %%
df.avg_salary.hist(bins=6,grid=True)

# %%
df.age.hist(bins=15,grid=False)

# %%
df.len_desc.hist(grid=False)

# %%
sns.scatterplot(x=df.len_desc,y=df.age,hue=df.avg_salary)
